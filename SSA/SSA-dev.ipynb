# %%
import numpy as np
import scipy.linalg as la
import matplotlib.pyplot as plt
np.set_printoptions(linewidth=85)

# %%
from ssa import BasicSSA
sqnce = BasicSSA(seq)
sqnce = sqnce(window=15,ngroups=3)

# %%
sqlen = 144
np.random.seed(256)
rng = np.linspace(0,2*np.pi,sqlen)
_seq = np.sin(rng) + 3*np.sin(2+rng)- 2*np.cos(7+rng)
seq = _seq + np.random.normal(0,1,size=len(_seq))
seq+=100
print(len(seq))
# Out:
# 144

# %%
m = np.mean(seq)
f,a = plt.subplots(figsize=(12,7))
a.plot(seq,'rx')
a.plot(seq,'b--')
a.plot([0,len(seq)],[m,m],'r.-')
a.plot(sqnce.components[0]+sqnce.components[2],'g.-')
plt.show()
